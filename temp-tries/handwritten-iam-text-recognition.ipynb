# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('iam_handwriting_word_database'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# iam_handwriting_word_database\words_new.txt
# iam_handwriting_word_database\iam_words\words.txt
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-02-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-05-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-06-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000u\a01-000u-06-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-00-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-01-10.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-02-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-03-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-04-10.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-000x\a01-000x-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-00-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-01-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-03-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-05-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-06-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-06-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-07-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-08-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-09-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-10-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003\a01-003-10-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-02-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-06-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-07-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-07-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-07-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-07-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-07-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-07-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-07-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-08-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-08-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-08-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-08-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-08-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-08-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-08-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-09-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-09-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-09-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-09-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-09-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-09-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-09-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003u\a01-003u-10-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-00-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-01-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-02-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-03-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-04-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-05-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-06-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-07-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-003x\a01-003x-08-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-00-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-03-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-04-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-05-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-06-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-06-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-07-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-08-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-08-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-08-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-08-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-08-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-08-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007\a01-007-08-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-00-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-03-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-05-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-07-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-07-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-07-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-07-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-07-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-07-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-07-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-08-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-08-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-08-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-08-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-08-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-08-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-08-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-09-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-09-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-09-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007u\a01-007u-09-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-00-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-01-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-02-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-03-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-04-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-05-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-06-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-007x\a01-007x-07-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-00-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-01-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-02-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-09.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-03-10.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-04-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-05-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-00.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-01.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-02.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-03.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-04.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-05.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-06.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-07.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-08.png
# iam_handwriting_word_database\iam_words\words\a01\a01-011\a01-011-06-09.png
# ...
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-03-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-03-09.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-03-10.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-04-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-05-09.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-06-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-07-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-08-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-08-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-08-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-08-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-013\d05-013-08-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-00-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-01-09.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-09.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-10.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-11.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-02-12.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-03-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-09.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-10.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-04-11.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-09.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-10.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-11.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-12.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-05-13.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-06-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-06-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-06-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-06-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-06-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-06-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-07-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-07-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-07-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-07-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-07-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-07-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-07-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-021\d05-021-08-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-00-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-00-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-00-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-00-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-00-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-00-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-00-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-01-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-01-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-01-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-01-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-01-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-01-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-01-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-02-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-03-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-04-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-05-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-06-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-06.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-07.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-07-08.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-08-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-08-01.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-08-02.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-08-03.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-08-04.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-08-05.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-09-00.png
# iam_handwriting_word_database\iam_words\words\d05\d05-025\d05-025-09-01.png
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# We can break the implementation of CRNN network into following steps:
#
# Import Data
#
# Data Preprocessing
#
# Model Building
#
# Defining Loss Function
#
# Training Model
#
# Decoding Outputs from Prediction

# %%
import numpy as np
import cv2
import os
import pandas as pd
import string
import matplotlib.pyplot as plt

from keras.preprocessing.sequence import pad_sequences

from keras.layers import Dense, LSTM, Reshape, BatchNormalization, Input, Conv2D, MaxPool2D, Lambda, Bidirectional
from keras.models import Model
from keras.activations import relu, sigmoid, softmax
import keras.backend as K

from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from PIL import Image

import tensorflow as tf

#ignore warnings in the output
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\shc\AppData\Local\Temp\ipykernel_1372\3611516016.py:27: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
images = []
labels = []

RECORDS_COUNT = 30000

# %% [markdown]
# **Intialization of variables**

# %%
train_images = []
train_labels = []
train_input_length = []
train_label_length = []
train_original_text = []

valid_images = []
valid_labels = []
valid_input_length = []
valid_label_length = []
valid_original_text = []

inputs_length = []
labels_length = []

# %% [markdown]
# **IAM DATASET**

# %%
with open('iam_handwriting_word_database/iam_words/words.txt') as f:
    contents = f.readlines()[18:22539]

lines = [line.strip() for line in contents] 
lines[-1]
# Out:
# 'b06-110-07-03 ok 173 987 2031 8 6 . .'

# %% [markdown]
# **DATA PREPROCESSING**

# %%
def process_image(img):
    """
    Converts image to shape (32, 128, 1) & normalize
    """
    w, h = img.shape
    
#     _, img = cv2.threshold(img, 
#                            128, 
#                            255, 
#                            cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    
    # Aspect Ratio Calculation
    new_w = 32
    new_h = int(h * (new_w / w))
    img = cv2.resize(img, (new_h, new_w))
    w, h = img.shape
    
    img = img.astype('float32')
    
    # Converts each to (32, 128, 1)
    if w < 32:
        add_zeros = np.full((32-w, h), 255)
        img = np.concatenate((img, add_zeros))
        w, h = img.shape
    
    if h < 128:
        add_zeros = np.full((w, 128-h), 255)
        img = np.concatenate((img, add_zeros), axis=1)
        w, h = img.shape
        
    if h > 128 or w > 32:
        dim = (128,32)
        img = cv2.resize(img, dim)
    
    img = cv2.subtract(255, img)
    
    img = np.expand_dims(img, axis=2)
    
    # Normalize 
    img = img / 255
    
    return img

# %% [markdown]
# **Label Encoding**

# %%
max_label_len = 0

char_list = "!\"#&'()*+,-./0123456789:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz" 

# string.ascii_letters + string.digits (Chars & Digits)
# or 
# "!\"#&'()*+,-./0123456789:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"

print(char_list, len(char_list))

def encode_to_labels(txt):
    # encoding each output word into digits
    dig_lst = []
    for index, chara in enumerate(txt):
        dig_lst.append(char_list.index(chara))
        
    return dig_lst
# Out:
# !"#&'()*+,-./0123456789:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz 78

# %%
for index, line in enumerate(lines):
    splits = line.split(' ')
    status = splits[1]
    
    if status == 'ok':
        word_id = splits[0]
        word = "".join(splits[8:])
        
        splits_id = word_id.split('-')
        filepath = 'iam_handwriting_word_database/iam_words/words/{}/{}-{}/{}.png'.format(splits_id[0], 
                                                  splits_id[0], 
                                                  splits_id[1], 
                                                  word_id)
      
        # process image
        img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
        try:
            img = process_image(img)
        except:
            continue
            
        # process label
        try:
            label = encode_to_labels(word)
        except:
            continue
        
        if index % 10 == 0:
            valid_images.append(img)
            valid_labels.append(label)
            valid_input_length.append(31)
            valid_label_length.append(len(word))
            valid_original_text.append(word)
        else:
            train_images.append(img)
            train_labels.append(label)
            train_input_length.append(31)
            train_label_length.append(len(word))
            train_original_text.append(word)
        
        if len(word) > max_label_len:
            max_label_len = len(word)
    
    if index >= RECORDS_COUNT:
        break

# %%
train_padded_label = pad_sequences(train_labels, 
                             maxlen=max_label_len, 
                             padding='post',
                             value=len(char_list))

valid_padded_label = pad_sequences(valid_labels, 
                             maxlen=max_label_len, 
                             padding='post',
                             value=len(char_list))

# %%
train_labels[3101]
# Out:
# [70, 67, 56, 65, 55, 60, 65, 58]

# %% [markdown]
# pad each output label to maximum text length

# %%
train_padded_label[3101]
# Out:
# array([70, 67, 56, 65, 55, 60, 65, 58, 78, 78, 78, 78, 78, 78, 78, 78, 78])

# %%
train_padded_label.shape, valid_padded_label.shape
# Out:
# ((18074, 17), (2007, 17))

# %%
train_images = np.asarray(train_images)
train_input_length = np.asarray(train_input_length)
train_label_length = np.asarray(train_label_length)

valid_images = np.asarray(valid_images)
valid_input_length = np.asarray(valid_input_length)
valid_label_length = np.asarray(valid_label_length)

# %% [markdown]
# Model Building and Description
#
# 1. Input shape for our architecture having an input image of height 32 and width 128.
# 2. Here we used seven convolution layers of which 6 are having kernel size (3,3) and the last one is of size (2.2). And the number of filters is increased from 64 to 512 layer by layer.
# 3. Two max-pooling layers are added with size (2,2) and then two max-pooling layers of size (2,1) are added to extract features with a larger width to predict long texts.
# 4. Also, we used batch normalization layers after fifth and sixth convolution layers which accelerates the training process.
# 5. Then we used a lambda function to squeeze the output from conv layer and make it compatible with LSTM layer.
# 6. Then used two Bidirectional LSTM layers each of which has 128 units. This RNN layer gives the output of size (batch_size, 31, 79). Where 79 is the total number of output classes including blank character.

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras import backend as tf_keras_backend
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten

tf_keras_backend.set_image_data_format('channels_last')
tf_keras_backend.image_data_format()
# Out:
# 'channels_last'

# %%
def Model1():
    # input with shape of height=32 and width=128 
    inputs = Input(shape=(32,128,1))

    # convolution layer with kernel size (3,3)
    conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
    # poolig layer with kernel size (2,2)
    pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)

    conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
    pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)

    conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)

    conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)
    # poolig layer with kernel size (2,1)
    pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)

    conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)
    # Batch normalization layer
    batch_norm_5 = BatchNormalization()(conv_5)

    conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
    batch_norm_6 = BatchNormalization()(conv_6)
    pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)

    conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)

    # Here we add the output_shape argument to the Lambda function
    squeezed = Lambda(lambda x: K.squeeze(x, 1), output_shape=lambda x: (x[0], x[2]))(conv_7)

    # Add an extra dimension for LSTM
    squeezed = tf.expand_dims(squeezed, axis=-1)

    # bidirectional LSTM layers with units=128
    blstm_1 = Bidirectional(LSTM(256, return_sequences=True, dropout = 0.2))(squeezed)
    blstm_2 = Bidirectional(LSTM(256, return_sequences=True, dropout = 0.2))(blstm_1)

    outputs = Dense(len(char_list)+1, activation = 'softmax')(blstm_2)

    # model to be used at test time
    act_model = Model(inputs, outputs)
    
    return act_model,outputs,inputs

# %%
act_model,outputs,inputs=Model1()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 act_model,outputs,inputs=Model1()
#
# Cell In[22], line 33, in Model1()
#      30 squeezed = Lambda(lambda x: K.squeeze(x, 1), output_shape=lambda x: (x[0], x[2]))(conv_7)
#      32 # Add an extra dimension for LSTM
# ---> 33 squeezed = tf.expand_dims(squeezed, axis=-1)
#      35 # bidirectional LSTM layers with units=128
#      36 blstm_1 = Bidirectional(LSTM(256, return_sequences=True, dropout = 0.2))(squeezed)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\common\keras_tensor.py:91, in KerasTensor.__tf_tensor__(self, dtype, name)
#      90 def __tf_tensor__(self, dtype=None, name=None):
# ---> 91     raise ValueError(
#      92         "A KerasTensor cannot be used as input to a TensorFlow function. "
#      93         "A KerasTensor is a symbolic placeholder for a shape and dtype, "
#      94         "used when constructing Keras Functional models "
#      95         "or Keras Functions. You can only use it as input to a Keras layer "
#      96         "or a Keras operation (from the namespaces `keras.layers` "
#      97         "and `keras.operations`). "
#      98         "You are likely doing something like:\n\n"
#      99         "```\n"
#     100         "x = Input(...)\n"
#     101         "...\n"
#     102         "tf_fn(x)  # Invalid.\n"
#     103         "```\n\n"
#     104         "What you should do instead is wrap `tf_fn` in a layer:\n\n"
#     105         "```\n"
#     106         "class MyLayer(Layer):\n"
#     107         "    def call(self, x):\n"
#     108         "        return tf_fn(x)\n\n"
#     109         "x = MyLayer()(x)\n"
#     110         "```\n"
#     111     )
#
# ValueError: A KerasTensor cannot be used as input to a TensorFlow function. A KerasTensor is a symbolic placeholder for a shape and dtype, used when constructing Keras Functional models or Keras Functions. You can only use it as input to a Keras layer or a Keras operation (from the namespaces `keras.layers` and `keras.operations`). You are likely doing something like:
#
# ```
# x = Input(...)
# ...
# tf_fn(x)  # Invalid.
# ```
#
# What you should do instead is wrap `tf_fn` in a layer:
#
# ```
# class MyLayer(Layer):
#     def call(self, x):
#         return tf_fn(x)
#
# x = MyLayer()(x)
# ```

# %%
act_model.summary()

# %%
the_labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, the_labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[inputs, the_labels, input_length, label_length], outputs=loss_out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 10
#       6     y_pred, labels, input_length, label_length = args
#       8     return K.ctc_batch_cost(labels, y_pred, input_length, label_length)
# ---> 10 loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, the_labels, input_length, label_length])
#      12 #model to be used at training time
#      13 model = Model(inputs=[inputs, the_labels, input_length, label_length], outputs=loss_out)
#
# NameError: name 'outputs' is not defined

# %% [markdown]
# **Training Model**

# %%
batch_size = 5
epochs = 25
e = str(epochs)
optimizer_name = 'sgd'

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer = optimizer_name, metrics=['accuracy'])

filepath="{}o-{}r-{}e-{}t-{}v.hdf5".format(optimizer_name,
                                          str(RECORDS_COUNT),
                                          str(epochs),
                                          str(train_images.shape[0]),
                                          str(valid_images.shape[0]))

checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
callbacks_list = [checkpoint]

# %%
history = model.fit(x=[train_images, train_padded_label, train_input_length, train_label_length],
                    y=np.zeros(len(train_images)),
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_data=([valid_images, valid_padded_label, valid_input_length, valid_label_length], [np.zeros(len(valid_images))]),
                    verbose=1,
                    callbacks=callbacks_list)

# %%
model.save(filepath='./model3.h5', overwrite=False, include_optimizer=True)

# %% [markdown]
# Performance Check:(Levenshtein Distance)
#
# For computing the performance, using the Jaro-Winkler algorithm to detect similarity between the captured text and the actual text.

# %%
filepath='./sgdo-30000r-25e-18074t-2007v.hdf5'
# load the saved best model weights
act_model.load_weights(filepath)

# predict outputs on validation images
prediction = act_model.predict(valid_images)
 
# use CTC decoder
decoded = K.ctc_decode(prediction, 
                       input_length=np.ones(prediction.shape[0]) * prediction.shape[1],
                       greedy=True)[0][0]
out = K.get_value(decoded)

import Levenshtein as lv

total_jaro = 0

# see the results
for i, x in enumerate(out):
    letters=''
    for p in x:
        if int(p) != -1:
            letters+=char_list[int(p)]
    total_jaro+=lv.jaro(letters, valid_original_text[i])
  
print('jaro :', total_jaro/len(out))

# %%
# predict outputs on validation images
i=2000
j=2004
prediction = act_model.predict(valid_images[i:j])
 
# use CTC decoder
decoded = K.ctc_decode(prediction,   
                       input_length=np.ones(prediction.shape[0]) * prediction.shape[1],
                       greedy=True)[0][0]

out = K.get_value(decoded)

# see the results
for _, x in enumerate(out):
    
    print("original_text =  ", valid_original_text[i])
    print("predicted text = ", end = '')
    for p in x:
        if int(p) != -1:
            print(char_list[int(p)], end = '')
    plt.imshow(valid_images[i].reshape(32,128), cmap=plt.cm.gray)
    plt.show()
    i+=1
    print('\n')

# %%
#plot accuracy and loss
def plotgraph(epochs, acc, val_acc):
    # Plot training & validation accuracy values
    plt.plot(epochs, acc, 'b')
    plt.plot(epochs, val_acc, 'r')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(loss)+1)

# %%
plotgraph(epochs, loss, val_loss)

# %%
plotgraph(epochs, acc, val_acc)

# %%
# get best model index
minimum_val_loss = np.min(history.history['val_loss'])
best_model_index = np.where(history.history['val_loss'] == minimum_val_loss)[0][0]

best_loss = str(history.history['loss'][best_model_index])
best_acc = str(history.history['accuracy'][best_model_index])
best_val_loss = str(history.history['val_loss'][best_model_index])
best_val_acc = str(history.history['val_accuracy'][best_model_index])

# %%
print(best_loss)
print(best_acc)
print(best_val_acc)
